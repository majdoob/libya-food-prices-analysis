# %% [markdown]
# # **Visualizing The Food Prices in Libya (June 2022)**

# %% [markdown]
# ***

# %% [markdown]
# <br>

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## <b>Import data</b>

# %%
df = pd.read_csv('https://data.humdata.org/dataset/dc632a15-d376-496f-976f-c3282e67bc28/resource/49e3a2ae-629e-46f3-8529-7e1fd0277b24/download/wfp_food_prices_lby.csv')

# %% [markdown]
# ## <b>EDA</b>

# %% [markdown]
# ### Genral Exploration

# %%
df
# Out:
#              date      admin1      admin2            market  \
# 0           #date  #adm1+name  #adm2+name  #loc+market+name
# 1      2017-06-15         NaN         NaN  National Average
# 2      2017-06-15        East       Derna             Derna
# 3      2017-06-15        East       Derna             Derna
# 4      2017-06-15        East       Derna             Derna
# ...           ...         ...         ...               ...
# 47883  2022-06-15        West       Zwara             Zwara
# 47884  2022-06-15        West       Zwara             Zwara
# 47885  2022-06-15        West       Zwara             Zwara
# 47886  2022-06-15        West       Zwara             Zwara
# 47887  2022-06-15        West       Zwara             Zwara
#
#                 latitude           longitude               category  \
# 0               #geo+lat            #geo+lon             #item+type
# 1                    NaN                 NaN               non-food
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47888 entries, 0 to 47887
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       47888 non-null  object
#  1   admin1     47847 non-null  object
#  2   admin2     47847 non-null  object
#  3   market     47888 non-null  object
#  4   latitude   47847 non-null  object
#  5   longitude  47847 non-null  object
#  6   category   47888 non-null  object
#  7   commodity  47888 non-null  object
#  8   unit       47888 non-null  object
#  9   priceflag  47888 non-null  object
#  10  pricetype  47888 non-null  object
#  11  currency   47888 non-null  object
#  12  price      47888 non-null  object
#  13  usdprice   47888 non-null  object
# dtypes: object(14)
# memory usage: 5.1+ MB

# %% [markdown]
# ### List columns

# %%
df.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'latitude', 'longitude',
#        'category', 'commodity', 'unit', 'priceflag', 'pricetype', 'currency',
#        'price', 'usdprice'],
#       dtype='object')

# %% [markdown]
# ### Explore Columns unique values

# %%
# category
# df.category.unique()
df.category.value_counts()
# Out:
# cereals and tubers       10482
# non-food                 10175
# miscellaneous food        7539
# meat, fish and eggs       6705
# vegetables and fruits     4187
# pulses and nuts           3599
# milk and dairy            3511
# oil and fats              1689
# #item+type                   1
# Name: category, dtype: int64

# %%
# commodity
# df.commodity.unique()
df.commodity.value_counts()
# Out:
# Beans                            1895
# Bread                            1818
# Rice                             1817
# Wheat flour                      1745
# Potatoes                         1709
# Eggs                             1706
# Salt                             1706
# Chickpeas                        1704
# Pasta                            1702
# Onions                           1702
# Milk (pasteurized)               1694
# Couscous                         1691
# Oil (vegetable)                  1689
# Meat (chicken)                   1688
# Tomatoes (paste)                 1685
# Tea (black)                      1680
# Milk (condensed)                 1677
# Fish (tuna, canned)              1671
# Tomatoes                         1670
# Sugar                            1667
# Meat (lamb)                      1640
# Water (drinking)                 1453
# Toothbrush                        925
# Handwash soap                     912
# Dishwashing liquid                893
# ...

# %%
# unit
# df.unit.unique()
df.unit.value_counts()
# Out:
# KG            18866
# L              6613
# 400 G          5284
# 30 pcs         2568
# 250 G          2481
# 5 pcs          1818
# 500 G          1702
# 200 ML         1677
# 200 G          1671
# Brush           925
# Bar             912
# 10 pcs          891
# 100 ML          887
# 250 ML          856
# 11 KG           695
# USD/LCU          41
# #item+unit        1
# Name: unit, dtype: int64

# %% [markdown]
# ### Query rows

# %%
df.query("market == 'National Average'")
# Out:
#              date admin1 admin2            market latitude longitude  \
# 1      2017-06-15    NaN    NaN  National Average      NaN       NaN
# 145    2017-07-15    NaN    NaN  National Average      NaN       NaN
# 301    2017-08-15    NaN    NaN  National Average      NaN       NaN
# 451    2017-09-15    NaN    NaN  National Average      NaN       NaN
# 626    2017-10-15    NaN    NaN  National Average      NaN       NaN
# 989    2017-11-15    NaN    NaN  National Average      NaN       NaN
# 1381   2017-12-15    NaN    NaN  National Average      NaN       NaN
# 1816   2018-01-15    NaN    NaN  National Average      NaN       NaN
# 2605   2018-02-15    NaN    NaN  National Average      NaN       NaN
# 3367   2018-03-15    NaN    NaN  National Average      NaN       NaN
# 4276   2018-04-15    NaN    NaN  National Average      NaN       NaN
# 5218   2018-05-15    NaN    NaN  National Average      NaN       NaN
# 6033   2018-06-15    NaN    NaN  National Average      NaN       NaN
# ...

# %% [markdown]
# ## <b>Data prepration/manupulation</b>

# %% [markdown]
# ### Delete irrelevant rows

# %%
# delete rows depndeing on the value

# df = df[df.market != 'National Average']
# df = df[df.market != '#loc+market+name']

# %% [markdown]
# ### Drop irrelevant columns

# %%
# df = df.drop(columns=['priceflag','pricetype','currency'])

# %%
df.head()
# Out:
#          date admin1 admin2 market           latitude          longitude  \
# 2  2017-06-15   East  Derna  Derna  32.75938034057617  22.63831901550293
# 3  2017-06-15   East  Derna  Derna  32.75938034057617  22.63831901550293
# 4  2017-06-15   East  Derna  Derna  32.75938034057617  22.63831901550293
# 5  2017-06-15   East  Derna  Derna  32.75938034057617  22.63831901550293
# 6  2017-06-15   East  Derna  Derna  32.75938034057617  22.63831901550293
#
#              category commodity   unit price usdprice
# 2  cereals and tubers     Bread  5 pcs   0.6   0.1194
# 3  cereals and tubers  Couscous     KG   3.5   0.6966
# 4  cereals and tubers     Pasta  500 G   1.9   0.3782
# 5  cereals and tubers  Potatoes     KG   3.0   0.5971
# 6  cereals and tubers      Rice     KG   2.8   0.5573

# %% [markdown]
# ### Rename Columns

# %%
df=df.rename(columns={'admin1':'region', 'admin2':'city','price':'lyd_price', 'usdprice':'usd_price'})

# %%
df.tail()
# Out:
#              date region   city market           latitude           longitude  \
# 47883  2022-06-15   West  Zwara  Zwara  32.91911315917969  12.077972412109375
# 47884  2022-06-15   West  Zwara  Zwara  32.91911315917969  12.077972412109375
# 47885  2022-06-15   West  Zwara  Zwara  32.91911315917969  12.077972412109375
# 47886  2022-06-15   West  Zwara  Zwara  32.91911315917969  12.077972412109375
# 47887  2022-06-15   West  Zwara  Zwara  32.91911315917969  12.077972412109375
#
#                     category         commodity   unit lyd_price usd_price
# 47883               non-food  Water (drinking)      L      0.29    0.0577
# 47884           oil and fats   Oil (vegetable)      L     11.95    2.3785
# 47885        pulses and nuts             Beans  400 G       2.5    0.4976
# 47886  vegetables and fruits            Onions     KG      3.25    0.6469
# 47887  vegetables and fruits          Tomatoes     KG      4.75    0.9454

# %% [markdown]
# ### Edit cells values

# %%
# create new dataframe as a checkpoint and filter for (jun 2022)
df1 = df.query("date == '2022-06-15'")

# %%
df1
# Out:
#              date region                city   market           latitude  \
# 47135  2022-06-15   East  Al Jabal Al Akhdar  Albayda  32.76095199584961
# 47136  2022-06-15   East  Al Jabal Al Akhdar  Albayda  32.76095199584961
# 47137  2022-06-15   East  Al Jabal Al Akhdar  Albayda  32.76095199584961
# 47138  2022-06-15   East  Al Jabal Al Akhdar  Albayda  32.76095199584961
# 47139  2022-06-15   East  Al Jabal Al Akhdar  Albayda  32.76095199584961
# ...           ...    ...                 ...      ...                ...
# 47883  2022-06-15   West               Zwara    Zwara  32.91911315917969
# 47884  2022-06-15   West               Zwara    Zwara  32.91911315917969
# 47885  2022-06-15   West               Zwara    Zwara  32.91911315917969
# 47886  2022-06-15   West               Zwara    Zwara  32.91911315917969
# 47887  2022-06-15   West               Zwara    Zwara  32.91911315917969
#
#                 longitude               category         commodity   unit  \
# ...

# %%
# reindex
# df1 = df1.reset_index()

# drop columns
# df1 = df1.drop(columns=['index'])

df1
# Out:
#            date region                city   market           latitude  \
# 0    2022-06-15   East  Al Jabal Al Akhdar  Albayda  32.76095199584961
# 1    2022-06-15   East  Al Jabal Al Akhdar  Albayda  32.76095199584961
# 2    2022-06-15   East  Al Jabal Al Akhdar  Albayda  32.76095199584961
# 3    2022-06-15   East  Al Jabal Al Akhdar  Albayda  32.76095199584961
# 4    2022-06-15   East  Al Jabal Al Akhdar  Albayda  32.76095199584961
# ..          ...    ...                 ...      ...                ...
# 748  2022-06-15   West               Zwara    Zwara  32.91911315917969
# 749  2022-06-15   West               Zwara    Zwara  32.91911315917969
# 750  2022-06-15   West               Zwara    Zwara  32.91911315917969
# 751  2022-06-15   West               Zwara    Zwara  32.91911315917969
# 752  2022-06-15   West               Zwara    Zwara  32.91911315917969
#
#               longitude               category         commodity   unit  \
# ...

# %%
# df1['date'] = df1['date'].str.replace('-15', '')
df1.head(2)
# Out:
#       date region                city   market           latitude  \
# 0  2022-06   East  Al Jabal Al Akhdar  Albayda  32.76095199584961
# 1  2022-06   East  Al Jabal Al Akhdar  Albayda  32.76095199584961
#
#            longitude            category commodity   unit lyd_price usd_price
# 0  21.75771713256836  cereals and tubers     Bread  5 pcs      1.25    0.2488
# 1  21.75771713256836  cereals and tubers  Couscous     KG      4.92    0.9793

# %% [markdown]
# ### drop all but 2022-06

# %%
df2 = df2[df2.date != '2022-06']
df2
# Out:
#           date region   city market           latitude           longitude  \
# 0      2017-06   East  Derna  Derna  32.75938034057617   22.63831901550293
# 1      2017-06   East  Derna  Derna  32.75938034057617   22.63831901550293
# 2      2017-06   East  Derna  Derna  32.75938034057617   22.63831901550293
# 3      2017-06   East  Derna  Derna  32.75938034057617   22.63831901550293
# 4      2017-06   East  Derna  Derna  32.75938034057617   22.63831901550293
# ...        ...    ...    ...    ...                ...                 ...
# 47088  2022-05   West  Zwara  Zwara  32.91911315917969  12.077972412109375
# 47089  2022-05   West  Zwara  Zwara  32.91911315917969  12.077972412109375
# 47090  2022-05   West  Zwara  Zwara  32.91911315917969  12.077972412109375
# 47091  2022-05   West  Zwara  Zwara  32.91911315917969  12.077972412109375
# 47092  2022-05   West  Zwara  Zwara  32.91911315917969  12.077972412109375
#
# ...

# %% [markdown]
# ## <b>Visulazation</b>

# %%
# 
fig = px.sunburst(
    data_frame = df1,
    path = ['country', 'region','city','market', 'category', 'commodity','lyd_price'], values='lyd_price',
    color = 'lyd_price', hover_data=['commodity', 'unit', 'lyd_price'], width = 1000, height =600,
    color_continuous_scale='reds', maxdepth=3, hover_name="lyd_price",
    title="<b>Food Price In Libya for June 2022</b>", template='ggplot2'
)
fig.show()

# %% [markdown]
# ## <b>Publish</b>
